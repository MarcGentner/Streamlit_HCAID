# %%
import pandas as pd
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Sports_Supplements.csv')

data = data.drop(['Unnamed: 18'], axis=1)
# # print(data.head())
data
# Out:
#              supplement                                           alt name  \
# 0                  AAKG                     L-arginine alpha-ketoglutarate
# 1                  AAKG                     L-arginine alpha-ketoglutarate
# 2           Baking soda    Bicarbonate of soda, sodium bicarbonate, NaHCO3
# 3                 BCAAs  branched-chain amino acids, leucine, isoleucin...
# 4                 BCAAs  branched-chain amino acids, leucine, isoleucin...
# ..                  ...                                                ...
# 91  Tribulus terrestris                            devil's thorn, tackweed
# 92             Tyrosine                                                NaN
# 93        Velvet antler              Deer velvet antler, elk velvet antler
# 94         Whey protein                                                NaN
# 95         Whey protein                                                NaN
#
# ...

# %%
# / drop nan values \

nan_values = data["N positive studies / trials"].isna().sum()



# data["N positive studies / trials"].fillna(0)
data["N positive studies / trials"] = data["N positive studies / trials"].fillna(0)
data["N positive studies / trials"]
# Print the number of NaN values in each column
print("Droped columns check: ", data.isna().sum())
# Out:
# Droped columns check:  supplement                              0
# alt name                               45
# evidence level                          0
# Claimed improved aspect of fitness      0
# fitness category                        0
# sport or exercise type tested           0
# OTW                                    68
# popularity                              0
# number of studies examined              0
# number of citations                     0
# efficacy                               96
# Unnamed: 11                            96
# Cochrane systematic review              0
# No. of individual studies / reviews     0
# N positive studies / trials             0
# % positive studies/ trials              0
# main study source                       0
# Link to main individual study           0
# Unnamed: 18                            96
# Link to individual study                0
# Link to individual study.1             33
# dtype: int64
